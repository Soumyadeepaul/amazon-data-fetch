# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path="E:\anaconda\chromedriver.exe")
driver.maximize_window()
driver.get('https://www.amazon.in/s?k=bags&page=17&crid=2M096C61O4MLT&qid=1679335533&sprefix=ba%2Caps%2C283&ref=sr_pg_16')
driver.implicitly_wait(5)
# Out:
# <ipython-input-110-b923eb10e83c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="E:\anaconda\chromedriver.exe")

# %%
df=pd.DataFrame(columns=['Product URL','Product Name','Product Price','Rating','Number of reviews'])

# %%
#we have to switch page manually
def scrap(div,df):
    for d in range(3,div-3):
        try:
            links=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[1]/h2/a')
            name=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[1]/h2/a/span')
            rating=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[2]/div/span[1]/span[1]')
            review=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[2]/div/span[2]/a/span')
            try:
                price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div[2]/a/span[1]/span[2]/span[2]')
            except:
                try:
                    price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div[2]/a/span[1]/span[2]/span[2]') 
                except:
                    try:
                        price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/a/span/span[2]/span[2]') 
                    except:
                        price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div/a/span[1]/span[2]/span[2]')
                    
        except:
            try:
                links=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[1]/h2/a')
                
                name=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[1]/h2/a/span')
                rating=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[2]/div/span[1]/span[1]')
                review=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[2]/div/span[2]/a/span')
                try:
                    price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div[2]/a/span[1]/span[2]/span[2]')
                except:
                    try:
                        price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div[2]/a/span[1]/span[2]/span[2]') 
                    except:
                        try:
                            price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div/div/a/span/span[2]/span[2]') 
                        except:
                            price=driver.find_element(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div['+str(d)+']/div/div/div/div/div/div[2]/div/div/div[3]/div[1]/div/div[1]/div/a/span[1]/span[2]/span[2]')
            except:    
                 continue    
        list1=[links.get_attribute('href'),name.text,price.text,rating.text,review.text] 
        df.loc[len(df)]=list1
    return df
divs=driver.find_elements(By.XPATH,'//*[@id="search"]/div[1]/div[1]/div/span[1]/div[1]/div')  
df=scrap(len(divs),df)

# %%
df
# Out:
#                                            Product URL  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2    https://www.amazon.in/American-Tourister-AMT-S...
# 3    https://www.amazon.in/Skybags-Brat-Black-Casua...
# 4    https://www.amazon.in/Wesley-Milestone-Waterpr...
# ..                                                 ...
# 433  https://www.amazon.in/Wildcraft-Streak-Laptop-...
# 434  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 435  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 436  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 437  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
#                                           Product Name Product Price  Rating  \
# 0    MOKOBARA The Zip Around Backpack | Water Resis...         2,999     5.0
# 1    uppercase Matrix Professional Anti-theft Lapto...         2,300     4.2
# ...

# %%
df=df.drop_duplicates()

# %%
df.to_csv('assignment_part1.csv')
